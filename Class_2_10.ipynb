# %% [markdown]
# <a href="https://colab.research.google.com/github/oliviapang/scratchpad/blob/main/Class_2_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/oliviapang/scratchpad
# %run ./scratchpad/get_data.py
# Out:
# Cloning into 'scratchpad'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 48 (delta 11), reused 5 (delta 5), pack-reused 28 (from 1)
# Receiving objects: 100% (48/48), 408.80 KiB | 12.39 MiB/s, done.
# Resolving deltas: 100% (16/16), done.
# ...
# Download complete
# Extracting data files...
# Data extracted

# %%
import pandas as pd

df = pd.read_csv('/content/data/craiglist_cville_cars_long.csv')

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

tdf = df.loc[:, ['price', 'age', 'miles', 'bodytype']]
print(tdf.shape)
tdf = tdf.dropna()
print(tdf.shape)

y = tdf['price']
x = tdf.loc[:, ['age', 'miles']]
type_ohc = pd.get_dummies(tdf['bodytype'], dtype = 'int', drop_first=True)
brand_ohc = pd.get_dummies(tdf['brand'], dtype = 'str', drop_first = True)
x = pd.concat([x, type_ohc], axis = 1)
# Out:
# (92, 4)
# (78, 4)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'brand'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-649992137.py in <cell line: 0>()
#      10 x = tdf.loc[:, ['age', 'miles']]
# ...
